# %%
pwd
# Out:
# u'F:\\ds'

# %%
cd F:\ds
# Out:
# F:\ds

# %%
pwd
# Out:
# u'F:\\ds'

# %%
import pandas as pd

# %%
df1 = pd.read_csv('dedup.csv')

# %%
df1 = pd.DataFrame(df1)

# %%
df.isnull().sum()
# Out:
# ln     0
# dob    0
# gn     0
# fn     0
# dtype: int64

# %%
df1.head()
# Out:
#              ln       dob gn       fn
# 0      SMITH JR  01/03/68  F  WILLIAM
# 1  ROTHMEYER JR  01/03/68  F  WILLIAM
# 2       ASBY JR  01/03/68  F  WILLIAM
# 3     SALTER JR  01/03/68  F  WILLIAM
# 4     SALTER JR  01/03/68  F  WILLIAM

# %%
df1.dtypes
# Out:
# ln     object
# dob    object
# gn     object
# fn     object
# dtype: object

# %%
df1
# Out:
#                 ln       dob gn            fn
# 0         SMITH JR  01/03/68  F       WILLIAM
# 1     ROTHMEYER JR  01/03/68  F       WILLIAM
# 2          ASBY JR  01/03/68  F       WILLIAM
# 3        SALTER JR  01/03/68  F       WILLIAM
# 4        SALTER JR  01/03/68  F       WILLIAM
# 5         BLAND JR  21/02/62  F       WILLIAM
# 6         BLAND JR  21/02/62  F       WILLIAM
# 7         BLAND JR  21/02/62  F       WILLIAM
# 8       SHAFFER JR  21/02/62  F       WILLIAM
# 9       SHAFFER JR  21/02/62  F       WILLIAM
# 10       BLAND III  21/02/62  F       WILLIAM
# 11        BLAND JR  21/02/62  F          BILL
# 12           BLAND  21/02/62  F       WILLIAM
# 13        BLAND JR  21/02/62  F       WILLIAM
# 14        BLAND JR  08/06/54  F       WILLIAM
# 15        BLAND JR  08/06/54  F       WILLIAM
# 16        BLAND JR  25/10/53  F       WILLIAM
# 17        BLAND JR  25/10/53  F       WILLIAM
# 18      SHAFFER JR  25/10/53  F       WILLIAM
# ...

# %%
df2 = df1.reindex(index = range(len(df1)))

# %%
df2
# Out:
#                 ln       dob gn            fn
# 0         SMITH JR  01/03/68  F       WILLIAM
# 1     ROTHMEYER JR  01/03/68  F       WILLIAM
# 2          ASBY JR  01/03/68  F       WILLIAM
# 3        SALTER JR  01/03/68  F       WILLIAM
# 4        SALTER JR  01/03/68  F       WILLIAM
# 5         BLAND JR  21/02/62  F       WILLIAM
# 6         BLAND JR  21/02/62  F       WILLIAM
# 7         BLAND JR  21/02/62  F       WILLIAM
# 8       SHAFFER JR  21/02/62  F       WILLIAM
# 9       SHAFFER JR  21/02/62  F       WILLIAM
# 10       BLAND III  21/02/62  F       WILLIAM
# 11        BLAND JR  21/02/62  F          BILL
# 12           BLAND  21/02/62  F       WILLIAM
# 13        BLAND JR  21/02/62  F       WILLIAM
# 14        BLAND JR  08/06/54  F       WILLIAM
# 15        BLAND JR  08/06/54  F       WILLIAM
# 16        BLAND JR  25/10/53  F       WILLIAM
# 17        BLAND JR  25/10/53  F       WILLIAM
# 18      SHAFFER JR  25/10/53  F       WILLIAM
# ...

# %%
df3 = pd.DataFrame(df2.ln.str.split(' ',1).tolist(),
                                   columns = ['ln','tag'])

# %%
df3[['fn','mn']] = pd.DataFrame(df2.fn.str.split(' ',1).tolist(),
                                   columns = ['fn','mn'])

# %%
df3['dob'] = df2['dob']
df3['gn'] = df2['gn']

# %%
df3.head()
# Out:
#           ln tag       fn    mn       dob gn
# 0      SMITH  JR  WILLIAM  None  01/03/68  F
# 1  ROTHMEYER  JR  WILLIAM  None  01/03/68  F
# 2       ASBY  JR  WILLIAM  None  01/03/68  F
# 3     SALTER  JR  WILLIAM  None  01/03/68  F
# 4     SALTER  JR  WILLIAM  None  01/03/68  F

# %%
gb = df3.groupby('dob')

# %%
gb.head()
# Out:
#              ln    tag        fn    mn       dob gn
# 0         SMITH     JR   WILLIAM  None  01/03/68  F
# 1     ROTHMEYER     JR   WILLIAM  None  01/03/68  F
# 2          ASBY     JR   WILLIAM  None  01/03/68  F
# 3        SALTER     JR   WILLIAM  None  01/03/68  F
# 4        SALTER     JR   WILLIAM  None  01/03/68  F
# 5         BLAND     JR   WILLIAM  None  21/02/62  F
# 6         BLAND     JR   WILLIAM  None  21/02/62  F
# 7         BLAND     JR   WILLIAM  None  21/02/62  F
# 8       SHAFFER     JR   WILLIAM  None  21/02/62  F
# 9       SHAFFER     JR   WILLIAM  None  21/02/62  F
# 14        BLAND     JR   WILLIAM  None  08/06/54  F
# 15        BLAND     JR   WILLIAM  None  08/06/54  F
# 16        BLAND     JR   WILLIAM  None  25/10/53  F
# 17        BLAND     JR   WILLIAM  None  25/10/53  F
# 18      SHAFFER     JR   WILLIAM  None  25/10/53  F
# 19       DUNCAN     JR    THOMAS  None  25/10/53  F
# 20      CARLSON     JR       ROY  None  25/10/53  F
# ...

# %%
list = []
for name,group in gb:
    print (name)
    print (group)
# Out:
# 01/03/68
#           ln tag       fn    mn       dob gn
# 0      SMITH  JR  WILLIAM  None  01/03/68  F
# 1  ROTHMEYER  JR  WILLIAM  None  01/03/68  F
# 2       ASBY  JR  WILLIAM  None  01/03/68  F
# 3     SALTER  JR  WILLIAM  None  01/03/68  F
# 4     SALTER  JR  WILLIAM  None  01/03/68  F
# 01/05/51
#             ln tag   fn    mn       dob gn
# 27  MICHAELSON  JR  ROY  None  01/05/51  M
# 06/12/37
#          ln    tag       fn    mn       dob gn
# 100  FUNARO  JONES  HARRIET  None  06/12/37  F
# 101  FUNARO      J  HARRIET  None  06/12/37  F
# 102  FUNARO   None  HARRIET  None  06/12/37  F
# 07/05/37
#          ln tag        fn    mn       dob gn
# 89  GRIFFIN  JR      DARL  None  07/05/37  M
# 90  GRIFFIN  JR  CLIFFORD  None  07/05/37  M
# 91  GRIFFIN  JR  CLIFFORD  None  07/05/37  M
# 92  GRIFFIN  JR  CLIFFORD  None  07/05/37  M
# 93  GRIFFIN  JR  CLARENCE  None  07/05/37  M
# 07/10/37
#             ln tag      fn    mn       dob gn
# ...

# %%
uq = pd.DataFrame()

# %%
uq = df3[:0]

# %%
uq.loc[0] = df3.loc[0]
# Out:
# C:\Users\rs091\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
uq
# Out:
#       ln tag       fn    mn       dob gn
# 0  SMITH  JR  WILLIAM  None  01/03/68  F

# %%
for name,group in gb:
    temp = pd.DataFrame(group)
    a = 0
    un = pd.DataFrame()
    un = temp[:0]
    for i,j in temp.iterrows():
        x = 0
        for k,l in un.iterrows():
            if(temp['fn'][i] == un['fn'][k]) and (temp['gn'][i] == un['gn'][k]) and (temp['ln'][i] == un['ln'][k]):
                x = x + 1
        if(x == 0):
            a = a + 1
            un.loc[a] = j
    print un
    uq = uq.append(un)
# Out:
# C:\Users\rs091\Anaconda2\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#           ln tag       fn    mn       dob gn
# 1      SMITH  JR  WILLIAM  None  01/03/68  F
# 2  ROTHMEYER  JR  WILLIAM  None  01/03/68  F
# 3       ASBY  JR  WILLIAM  None  01/03/68  F
# 4     SALTER  JR  WILLIAM  None  01/03/68  F
#            ln tag   fn    mn       dob gn
# 1  MICHAELSON  JR  ROY  None  01/05/51  M
#        ln    tag       fn    mn       dob gn
# 1  FUNARO  JONES  HARRIET  None  06/12/37  F
#         ln tag        fn    mn       dob gn
# 1  GRIFFIN  JR      DARL  None  07/05/37  M
# 2  GRIFFIN  JR  CLIFFORD  None  07/05/37  M
# 3  GRIFFIN  JR  CLARENCE  None  07/05/37  M
#            ln tag      fn    mn       dob gn
# ...

# %%
uq.head()
# Out:
#           ln tag       fn    mn       dob gn
# 0      SMITH  JR  WILLIAM  None  01/03/68  F
# 1      SMITH  JR  WILLIAM  None  01/03/68  F
# 2  ROTHMEYER  JR  WILLIAM  None  01/03/68  F
# 3       ASBY  JR  WILLIAM  None  01/03/68  F
# 4     SALTER  JR  WILLIAM  None  01/03/68  F

# %%
uq.index = range(len(uq))

# %%
uq.shape
# Out:
# (55, 6)

# %%
uq.to_csv('cample_output.csv')
